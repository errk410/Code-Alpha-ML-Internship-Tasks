# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music = pd.read_csv('/content/data_by_genres.csv')
music
# Out:
#       mode                  genres  acousticness  danceability   duration_ms  \
# 0        1  21st century classical      0.979333      0.162883  1.602977e+05
# 1        1                   432hz      0.494780      0.299333  1.048887e+06
# 2        1                   8-bit      0.762000      0.712000  1.151770e+05
# 3        1                      []      0.651417      0.529093  2.328809e+05
# 4        1              a cappella      0.676557      0.538961  1.906285e+05
# ...    ...                     ...           ...           ...           ...
# 2968     1                    zolo      0.222625      0.547082  2.580991e+05
# 2969     0                 zouglou      0.161000      0.863000  2.063200e+05
# 2970     1                    zouk      0.263261      0.748889  3.060728e+05
# 2971     0            zurich indie      0.993000      0.705667  1.984173e+05
# 2972     1                  zydeco      0.421038      0.629409  1.716717e+05
#
# ...

# %%
music.shape
# Out:
# (2973, 14)

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2973 entries, 0 to 2972
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              2973 non-null   int64
#  1   genres            2973 non-null   object
#  2   acousticness      2973 non-null   float64
#  3   danceability      2973 non-null   float64
#  4   duration_ms       2973 non-null   float64
#  5   energy            2973 non-null   float64
#  6   instrumentalness  2973 non-null   float64
#  7   liveness          2973 non-null   float64
#  8   loudness          2973 non-null   float64
#  9   speechiness       2973 non-null   float64
#  10  tempo             2973 non-null   float64
#  11  valence           2973 non-null   float64
#  12  popularity        2973 non-null   float64
#  13  key               2973 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 325.3+ KB

# %%
music.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %% [markdown]
# Checking whether **genres** is actually in a list format:

# %%
music['genres'].values[0]
# Out:
# '21st century classical'

# %%
music['genres'].unique().shape
# Out:
# (2973,)

# %%
music.describe()
# Out:
#               mode  acousticness  danceability   duration_ms       energy  \
# count  2973.000000   2973.000000   2973.000000  2.973000e+03  2973.000000
# mean      0.833165      0.401241      0.537187  2.517209e+05     0.561143
# std       0.372891      0.319760      0.150668  9.465686e+04     0.234486
# min       0.000000      0.000003      0.056900  3.094600e+04     0.001002
# 25%       1.000000      0.119050      0.441202  2.063788e+05     0.395058
# 50%       1.000000      0.321745      0.546496  2.375453e+05     0.601195
# 75%       1.000000      0.673991      0.647500  2.772720e+05     0.730127
# max       1.000000      0.996000      0.929000  2.382587e+06     0.994667
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       2973.000000  2973.000000  2973.000000  2973.000000  2973.000000
# mean           0.211366     0.192800   -10.509848     0.083588   119.018723
# ...

# %%
music.isnull().sum()
# Out:
# mode                0
# genres              0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# key                 0
# dtype: int64

# %%
music.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
plt.figure(figsize=(35,15))

sns.heatmap(music.corr(),vmax=1, square=True, annot=True, cmap='viridis')
plt.title('Correlation between different attributes')
plt.show()
# Out:
# <ipython-input-11-99397769610c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(music.corr(),vmax=1, square=True, annot=True, cmap='viridis')

# %%
from yellowbrick.target import FeatureCorrelation

feature_names = ['mode', 'acousticness', 'danceability', 'duration_ms',
       'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
       'tempo', 'valence', 'key']

X, y = music[feature_names], music['popularity']

# Create a list of the feature names
features = np.array(feature_names)

# Instantiate the visualizer
visualizer = FeatureCorrelation(labels=features)

plt.rcParams['figure.figsize']=(20,20)
visualizer.fit(X, y)     # Fit the data to the visualizer
visualizer.show()
# Out:
# <Axes: title={'center': 'Features correlation with dependent variable'}, xlabel='Pearson Correlation'>

# %% [markdown]
# #**Characteristics of Different Genres**

# %%
import plotly.express as px

top10_genres = music.nlargest(10, 'popularity')

fig = px.bar(top10_genres, x='genres', y=['valence', 'energy', 'danceability', 'acousticness'], barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler

# %%
# Normalize numerical columns
scaler = MinMaxScaler()
numerical_cols = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness',
                  'loudness', 'speechiness', 'tempo', 'valence', 'popularity']
music[numerical_cols] = scaler.fit_transform(music[numerical_cols])

# %%
# Example: Recommend songs similar to a given song
song_to_compare = music[music['mode'] == 1].iloc[0]  # Choosing a song (mode 1)

# %%
# Compute similarity based on selected features
music['similarity'] = music[numerical_cols].apply(lambda x: cosine_similarity([song_to_compare[numerical_cols]], [x])[0][0], axis=1)

# %%
# Recommend top 15 similar songs
top_recommendations = music[music['mode'] == 1].nlargest(15, 'similarity')
print(top_recommendations[['genres', 'similarity']])
# Out:
#                                genres  similarity
# 0              21st century classical    1.000000
# 2822        ukrainian classical piano    0.970028
# 485                     chamber choir    0.968843
# 335         brazilian classical piano    0.968217
# 641                    classical horn    0.967712
# 327                       boy soprano    0.966774
# 1322                  hungarian choir    0.965505
# 2525                        sound art    0.959785
# 1323  hungarian classical performance    0.959322
# 2382          russian classical piano    0.959216
# 679            contemporary classical    0.959070
# 633                   classical cello    0.958833
# 2596                  streichquartett    0.958770
# 2821              ukrainian classical    0.957953
# 2391                russian orchestra    0.957570
